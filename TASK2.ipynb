# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/titanic.csv")

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 882         0       2                              Montvila, Rev. Juozas
# 883         1       1                       Graham, Miss. Margaret Edith
# 884         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 885         1       1                              Behr, Mr. Karl Howell
# 886         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        T

# %%
df.tail()
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 882         0       2                     Montvila, Rev. Juozas    male  27.0
# 883         1       1              Graham, Miss. Margaret Edith  female  19.0
# 884         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 885         1       1                     Behr, Mr. Karl Howell    male  26.0
# 886         0       3                       Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch      Ticket   Fare Cabin Embarked
# 882      0      0      211536  13.00   NaN        S
# 883      0      0      112053  30.00   B42        S
# 884      1      2  W./C. 6607  23.45   NaN        S
# 885      0      0      111369  30.00  C148        C
# 886      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (887, 11)

# %%
len(df[df.Survived==True])#survived
# Out:
# 340

# %%
len(df)-len(df[df.Survived==True])# notsurvived
# Out:
# 547

# %%
df[df['Age'].isnull()]
# Out:
#      Survived  Pclass                                            Name     Sex  \
# 5           0       3                                Moran, Mr. James    male
# 22          0       3                         Emir, Mr. Farred Chehab    male
# 24          1       3                   O'Dwyer, Miss. Ellen "Nellie"  female
# 25          0       3                             Todoroff, Mr. Lalio    male
# 27          1       1  Spencer, Mrs. William Augustus (Marie Eugenie)  female
# ..        ...     ...                                             ...     ...
# 855         0       3                                Razi, Mr. Raihed    male
# 859         0       3               Sage, Miss. Dorothy Edith "Dolly"  female
# 864         0       3                     van Melkebeke, Mr. Philemon    male
# 874         0       3                              Laleff, Mr. Kristo    male
# 884         0       3        Johnston, Miss. Catherine Helen "Carrie"  female
#
# ...

# %%
df.dropna(subset=['Age'])
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 881         0       3               Rice, Mrs. William (Margaret Norton)
# 882         0       2                              Montvila, Rev. Juozas
# 883         1       1                       Graham, Miss. Margaret Edith
# 885         1       1                              Behr, Mr. Karl Howell
# 886         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
 a = df[df.Survived == True]
 a[['Name','Age']]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 871                   Najib, Miss. Adele Kiamie "Jane"  15.0
# 875      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 876       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 883                       Graham, Miss. Margaret Edith  19.0
# 885                              Behr, Mr. Karl Howell  26.0
#
# [340 rows x 2 columns]

# %%
df.select_dtypes(include='number')
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 882         0       2  27.0      0      0  13.0000
# 883         1       1  19.0      0      0  30.0000
# 884         0       3   NaN      1      2  23.4500
# 885         1       1  26.0      0      0  30.0000
# 886         0       3  32.0      0      0   7.7500
#
# [887 rows x 6 columns]

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.countplot(x = "Sex" ,data = a,color="red",palette="Set2",hue="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x ="Pclass",data = a,palette="Set3",hue="Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>
